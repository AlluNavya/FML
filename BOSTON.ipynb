# %% [markdown]
# <a href="https://colab.research.google.com/github/AlluNavya/FML/blob/main/BOSTON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
data=pd.read_csv("boston.csv")
print(data)
data.head()
data.tail()

# %%
X=data.drop('medv',axis=1).values
y=data['medv'].values
print(X)
print(y)

# %%
X_rooms=X[:,5]
print(X_rooms)
type(X_rooms),type(y)

# %%
X_rooms.shape
# Out:
# (506,)

# %%
X_rooms=X_rooms.reshape(-1,1)
print(X_rooms)
y=y.reshape(-1,1)

# %%
X_rooms.shape,y.shape
# Out:
# ((506, 1), (506, 1))

# %%
plt.scatter(X_rooms,y)
plt.xlabel('no.of houses')
plt.ylabel('cost of houses')
plt.show()

# %%
reg = linear_model.LinearRegression()
reg.fit(X_rooms, y)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
y_pred=reg.predict(X_rooms)
print(y_pred)

# %%
print(f'mae={mean_absolute_error(y,y_pred)}')
print(f'mse={mean_squared_error(y,y_pred)}')
print(f'rscore={r2_score(y,y_pred)}')
print(f'RMSE = {np.sqrt(mean_squared_error(y, y_pred))}')
# Out:
# mae=4.4477729015322325
# mse=43.60055177116956
# rscore=0.48352545599133423
# RMSE = 6.603071389222561

# %%
plt.scatter(X_rooms,y, color='lightpink')
plt.plot(X_rooms,reg.predict(X_rooms),color="black")
plt.show()

# %%
prediction_space = np.linspace(min(X_rooms), max(X_rooms)).reshape(-1,1)

plt.scatter(X_rooms, y, color='blue')
plt.plot(prediction_space, reg.predict(prediction_space), color='black', linewidth=3)
plt.show()
